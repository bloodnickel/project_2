# %%
import pandas as pd
import numpy as np


import os
print(os.getcwd())        # full path of the current directory
print(os.listdir('.'))    # list files/folders in that directory

df = pd.read_csv("/Users/huss/data-processing/week5/group_project/project_2/1_Source_Files/df_final_experiment_clients.txt")
df

df_gender = pd.read_csv("/Users/huss/data-processing/week5/group_project/project_2/1.1_Clean_Files/df1_demo_clean.csv")
df_gender
# Out:
# /Users/huss/data-processing/week5/group_project/project_2/2_Python_Notebook
# ['.DS_Store', 'Johannes.ipynb', 'Stuck_Husseim.ipynb', '.ipynb_checkpoints', 'mykyta.ipynb']
#        client_id  client_tenure_years  client_tenure_months  client_age  \
# 0         836976                    6                    73        60.5
# 1        2304905                    7                    94        58.0
# 2        1439522                    5                    64        32.0
# 3        1562045                   16                   198        49.0
# 4        5126305                   12                   145        33.0
# ...          ...                  ...                   ...         ...
# 70590    7993686                    4                    56        38.5
# 70591    8981690                   12                   148        31.0
# 70592     333913                   16                   198        61.5
# 70593    1573142                   21                   255        68.0
# ...

# %%
df["Variation"] = df["Variation"].fillna("empty")
df["Variation"].replace({"NaN": pd.NA})
df["Variation"].value_counts()
# Out:
# Variation
# Test       26968
# Control    23532
# empty      20109
# Name: count, dtype: int64

# %%
df.drop_duplicates()
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
output_path = "../1.1_Clean_Files/df_final_experiment_clients_clean.csv"

df.to_csv(output_path, index=False)

# %%
print(df.head(5))
print(df.tail(5))
print(df.info())
print(df.info(memory_usage="deep"))
print(df.describe())
print(df.describe(include="all"))
print(df.shape)
print(df.dtypes)
print(df.columns)
print(df.index)
print(df.values)
print(df.empty)
print(df.ndim)
print(df.size)
print(df.memory_usage(deep=True))
print(df.T)
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control
#        client_id Variation
# 70604    2443347     empty
# 70605    8788427     empty
# 70606     266828     empty
# 70607    1266421     empty
# 70608    9895983     empty
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  70609 non-null  int64
#  1   Variation  70609 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  70609 non-null  int64
#  1   Variation  70609 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 4.2 MB
# None
# ...

# %%
gender_distribution = (df_gender["gender"].value_counts().reset_index())

gender_distribution.columns = ["gender", "client_count"]


display(gender_distribution)
# Out:
#     gender  client_count
# 0  Unknown         24125
# 1     Male         23724
# 2   Female         22746

# %%
import matplotlib.pyplot as plt

ax = df_gender.plot.barh(
    y="count",            # numeric column
    legend=False,
    figsize=(6, 3)
)

ax.set_xlabel("Count")
ax.set_ylabel("Gender")
ax.set_title("Horizontal Bar Chart by Gender")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 3
#       1 import matplotlib.pyplot as plt
# ...
