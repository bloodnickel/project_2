# %%
import pandas as pd
from pathlib import Path

p = Path("1_Source Files/df_final_demo.txt")        # adjust path relative to your workspace or absolute path
df = pd.read_csv(p, sep=",")       # use sep="," or sep="\t" or sep="|" etc.
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 from pathlib import Path
#       4 p = Path("1_Source Files/df_final_demo.txt")        # adjust path relative to your workspace or absolute path
#
# ModuleNotFoundError: No module named 'pandas'

# %%
p1 = Path("1_Source Files/df_final_experiment_clients.txt")        # adjust path relative to your workspace or absolute path
df1 = pd.read_csv(p1, sep=",")       # use sep="," or sep="\t" or sep="|" etc.
print(df1.head())
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
p2 = Path("1_Source Files/df_final_web_data_pt_1.txt")        # adjust path relative to your workspace or absolute path
df2 = pd.read_csv(p2, sep=",")       # use sep="," or sep="\t" or sep="|" etc.
print(df2.head())
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
p3 = Path("1_Source Files/df_final_web_data_pt_2.txt")        # adjust path relative to your workspace or absolute path
df3 = pd.read_csv(p3, sep=",")       # use sep="," or sep="\t" or sep="|" etc.
print(df3.head())
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %%
#======================================================================================================================================================================================================================================================
#Husseim

# %%
df_client = pd.read_csv("./1_Source Files/df_final_experiment_clients.txt", sep=",")

# %%
#======================================================================================================================================================================================================================================================
#Johannes

# %%
#======================================================================================================================================================================================================================================================
#Mykyta
